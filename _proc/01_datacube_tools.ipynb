# %% [raw]
# ---
# output-file: datacube_tools.html
# title: datacube_tools
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(DATACUBETOOLS)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/datacube_tools.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### DATACUBETOOLS
#
# >      DATACUBETOOLS (use_catalog='all')
#
# class to encapsulate discovery and interaction with ITS_LIVE (its-live.jpl.nasa.gov) datacubes on AWS s3

# %%
#| echo: false
#| output: asis
show_doc(timeseriesException)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/datacube_tools.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### timeseriesException
#
#
#
# Common base class for all non-exit exceptions.
