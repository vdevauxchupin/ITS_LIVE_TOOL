# %% [raw]
# ---
# output-file: obj_setup.html
# title: '04: access_setup -- Data setup + prep'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## imports

# %% [markdown]
# ## Defining classes

# %%
#| echo: false
#| output: asis
show_doc(point_to_gdf)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### point_to_gdf
#
# >      point_to_gdf (point_ls)
#
# creates a geodataframe from a given point
#
# input: list of [x,y] coords
# output: geopandas gdf of point, in epsg:4326

# %%
#| echo: false
#| output: asis
show_doc(Glacier_Centerline)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L80){target="_blank" style="float:right; font-size:smaller"}
#
# ### Glacier_Centerline
#
# >      Glacier_Centerline (name, rgi_id)
#
# class to hold all data associated with a centerline

# %%
#| echo: false
#| output: asis
show_doc(Glacier)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L190){target="_blank" style="float:right; font-size:smaller"}
#
# ### Glacier
#
# >      Glacier (name, rgi_id, utm_crs, creation_type, rgi_outline_from_widget,
# >               itslive_url)
#
# class to hold all data associated with individual glacier
# inputs: name (str), rgi_id (str), working_dir_path (str, where oggm data should be written)
# url (str, url to oggm prepro data), centerline path (str, path to locally stored
#
# NOTE: now a 'creation_flag' must be passed. this specifies if the object was created manually or
# directly from an interaction with the widget. If created from the widget, it takes the rgi outline
# from the clicked data, if created manually it accesses via request

# %%
#| echo: false
#| output: asis
show_doc(calc_min_tbaseline)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L396){target="_blank" style="float:right; font-size:smaller"}
#
# ### calc_min_tbaseline
#
# >      calc_min_tbaseline (Point)

# %%
#| echo: false
#| output: asis
show_doc(Glacier_Point)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L251){target="_blank" style="float:right; font-size:smaller"}
#
# ### Glacier_Point
#
# >      Glacier_Point (name, label, rgi_id, point_coords_latlon, var_ls)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Selecting data

# %% [markdown]
# ## Creating objects of [`Glacier`](https://e-marshall.github.io/ITS_LIVE_TOOL/obj_setup.html#glacier), [`Glacier_Centerline`](https://e-marshall.github.io/ITS_LIVE_TOOL/obj_setup.html#glacier_centerline), [`Glacier_Point`](https://e-marshall.github.io/ITS_LIVE_TOOL/obj_setup.html#glacier_point) classes

# %% [markdown]
# ### Create directly from widget

# %%
#| echo: false
#| output: asis
show_doc(create_glacier_from_click)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L416){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_glacier_from_click
#
# >      create_glacier_from_click (w_obj, i)
#
# this function takes clicked information (from a single click, not all clicked points) and returns a `Glacier` type object

# %%
#| echo: false
#| output: asis
show_doc(create_glacier_point_from_click)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L430){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_glacier_point_from_click
#
# >      create_glacier_point_from_click (w_obj, i, label)

# %%
#| echo: false
#| output: asis
show_doc(create_glacier_centerline_from_click)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L439){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_glacier_centerline_from_click
#
# >      create_glacier_centerline_from_click (w_obj, i)

# %%
#| echo: false
#| output: asis
show_doc(create_multiple_glacier_objs)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L446){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_multiple_glacier_objs
#
# >      create_multiple_glacier_objs (w_obj)

# %%
#| echo: false
#| output: asis
show_doc(create_multiple_glacier_point_objs)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L458){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_multiple_glacier_point_objs
#
# >      create_multiple_glacier_point_objs (w_obj)

# %%
#| echo: false
#| output: asis
show_doc(create_multiple_glacier_centerline_objs)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L473){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_multiple_glacier_centerline_objs
#
# >      create_multiple_glacier_centerline_objs (w_obj)

# %% [markdown]
# ### Create manually

# %%
#| echo: false
#| output: asis
show_doc(return_clicked_info)
# Out:
# ---
#
# [source](https://github.com/e-marshall/ITS_LIVE_TOOL/blob/main/ITS_LIVE_TOOL/obj_setup.py#L485){target="_blank" style="float:right; font-size:smaller"}
#
# ### return_clicked_info
#
# >      return_clicked_info (clicked_widget)
#
# this function formats information from a user click on the Widget object.
# The output is a tuple with the form (coordinate list of clicked point, gpd.geodataframe with rgi info of clicked glacier, url of itslive zarr datacube covering clicked point

# %% [markdown]
# ### Glacier
